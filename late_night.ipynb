# %%
import pandas as pd

# %%
df = pd.read_csv("late-night-preferential-runway-use-1.csv", sep = ',')

# %%
df.head()
# Out:
#    index  Year  Month  01L/R 01L/R Percent of Departures  10L/R  \
# 0      0  2005      1     14                          6%    164
# 1      1  2005      2     14                          7%    158
# 2      2  2005      3     10                          4%    165
# 3      3  2005      4     26                          9%     99
# 4      4  2005      5     36                         10%     90
#
#   10L/R Percent of Departures  19L/R 19L/R Percent of Departures  28L/R  \
# 0                         71%      4                          2%     49
# 1                         80%      0                          0%     25
# 2                         69%      0                          0%     65
# 3                         32%      0                          0%    180
# 4                         24%      0                          0%    242
#
#   28L/R Percent of Departures
# 0                         21%
# 1                         13%
# 2                         27%
# ...
